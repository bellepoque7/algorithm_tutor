# %%
def countLetters(word):
    counter = {}
    for letter in word:
        if letter not in counter:
            counter[letter] = 0
        counter[letter] += 1
    print(counter)
countLetters('abbc')
# Out:
# {'a': 1, 'b': 2, 'c': 1}

# %%
def countLetters(word):
    counter = {}
    for letter in word:
        counter.setdefault(letter, 0)
        counter[letter] += 1
    print(counter)
countLetters('abbc')
# Out:
# {'a': 1, 'b': 2, 'c': 1}

# %%
from collections import defaultdict

def countLetters(word):
    #기본적으로 value가 저장될 데이터타입을 지정(int)
    counter = defaultdict(int)
    for letter in word:
        counter[letter] += 1
    print(counter)
countLetters('abbc')
# Out:
# defaultdict(<class 'int'>, {'a': 1, 'b': 2, 'c': 1})

# %% [markdown]
# - 집합자료형 set
#
# 1. 중복제거
# 2. 순서가없음(인덱스 x)
# 3. 합(|, union),차집합(-,difference),교집합(&, intersection) 가능
#
# https://wiki.python.org/moin/TimeComplexity

# %%
## set 함수
my_set = set([1,2,3,3,4,4])
my_set
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# - 더하기

# %%
my_set.add(5)
my_set
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# - 합집합

# %%
s1 = {1,2,3}
s2 = {4,5,6}

# %% [markdown]
# - 차집합

# %% [markdown]
# - 교집합

# %% [markdown]
# ![image.png](attachment:image.png)
